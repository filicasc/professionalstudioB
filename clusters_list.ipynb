# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from sklearn.cluster import KMeans

# %%
X = np.genfromtxt('output/file.csv', delimiter=',')
X = np.delete(X, 0, 1)
X = np.delete(X, 0, 0)

# %%
print (X)
# Out:
# [[ 2.61999774  4.28457975]
#  [-1.62296033  8.27779293]
#  [ 0.23010872 10.23365593]
#  ...
#  [ 3.20058846  3.90179801]
#  [-2.44800448  7.1401062 ]
#  [ 3.63669181  3.36589718]]

# %%
plt.scatter(X[:,0],X[:,1], label='True Position')

# %%
kmeans = KMeans(n_clusters=7)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=7)

# %%
print(kmeans.cluster_centers_)
# Out:
# [[-3.19635336  0.35619866]
#  [ 0.7496262   8.82278566]
#  [13.61967352 13.68775708]
#  [-2.67936715 14.05730995]
#  [ 3.49841487  3.80424211]
#  [ 3.92263782 11.97928198]
#  [-0.33665692  6.47222726]]

# %%
print(kmeans.labels_)
# Out:
# [4 6 1 6 4 4 4 6 6 6 6 6 6 6 2 2 2 4 6 4 6 0 6 6 6 1 4 6 6 1 4 6 6 1 6 4 6
#  0 6 5 6 4 6 1 5 5 1 6 6 0 1 6 0 6 1 2 6 1 1 6 6 4 6 1 4 6 3 6 6 4 6 6 1 4
#  6 4 6 0 6 6 3 4 1 6 6 6 1 0 6 6 4 4 1 6 3 5 1 1 4 6 3 3 6 1 6 1 1 2 4 2 6
#  5 1 4 5 1 3 3 6 6 1 1 6 3 6 6 4 5 5 2 6 1 6 1 4 1 6 1 1 1 1 0 1 1 3 0 1 2
#  2 4 5 6 6 6 6 1 2 6 2 3 1 1 5 0 0 5 2 4 0 6 1 2 4 4 2 1 6 0 6 1 6 1 1 1 2
#  6 6 6 6 1 6 1 1 1 1 1 0 5 1 1 1 0 4 3 6 6 6 6 1 6 1 6 6 6 1 5 1 6 1 4 0 0
#  1 5 6 1 6 6 4 1 5 6 6 6 3 6 4 0 3 4 6 6 4 1 4 4 6 6 6 1 6 4 1 0 4 6 1 6 1
#  1 1 4 6 6 1 3 6 3 0 6 3 5 6 3 1 1 1 1 6 1 1 1 4 6 1 4 1 6 2 1 6 6 6 1 1 6
#  0 0 1 1 1 1 6 4 6 3 4 6 6 1 3 1 6 1 3 3 1 1 5 4 5 6 6 6 6 4 6 4 6 5 6 6 2
#  1 6 5 2 1 6 1 5 2 1 6 6 1 6 1 6 6 0 5 6 6 1 5 6 6 1 2 6 4 2 3 4 6 3 6 1 1
#  1 4 0 3 6 1 2 1 2 4 6 0 5 1 1 1 5 6 6 6 6 6 0 4 6 6 6 6 1 4 1 1 1 5 6 1 0
#  1 2 6 1 1 1 3 5 0 1 1 6 2 0 6 6 2 6 6 6 3 1 6 6 4 6 3 3 3 6 6 1 1 1 6 4 1
#  6 6 6 1 3 6 1 6 1 1 1 6 0 4 1 4 6 1 1 1 6 1 6 4 1 1 5 1 0 6 6 4 0 3 4 4 6
#  2 6 1 6 6 5 1 1 6 1 6 1 5 2 6 6 5 4 6 1 1 4 6 4]

# %%
plt.scatter(X[:,0],X[:,1], c=kmeans.labels_, cmap='rainbow')

# %%
plt.scatter(X[:,0], X[:,1], c=kmeans.labels_, cmap='rainbow')
plt.scatter(kmeans.cluster_centers_[:,0] ,kmeans.cluster_centers_[:,1], color='black')
